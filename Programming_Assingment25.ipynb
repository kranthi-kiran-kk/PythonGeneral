# %%
# Assignment 25
# Question1
# Create a function that takes three integer arguments (a, b, c) and returns the amount of integers which are of equal value.
# Examples
# equal(3, 4, 3) ➞ 2

# equal(1, 1, 1) ➞ 3

# equal(3, 4, 1) ➞ 0 
# Notes
# Your function must return 0, 2 or 3.

def equal(a,b,c):
    list_in = [a,b,c]
    count = 0
    for ele in list_in:
        if list_in.count(ele) >1:
            count+= 1
            return list_in.count(ele)
    if count == 0:
        return 0

print(f'equal(3, 4, 3) : {equal(3, 4, 3)}')
print(f'equal(1, 1, 1) : {equal(1, 1, 1)}')
print(f'equal(3, 4, 1) : {equal(3, 4, 1)}')

# %%
# Question2
# Write a function that converts a dictionary into a list of keys-values tuples.
# Examples
# dict_to_list({
#   "D": 1,
#   "B": 2,
#   "C": 3
# }) ➞ [("B", 2), ("C", 3), ("D", 1)]

# dict_to_list({
#   "likes": 2,
#   "dislikes": 3,
#   "followers": 10
# }) ➞ [("dislikes", 3), ("followers", 10), ("likes", 2)]
# Notes
# Return the elements in the list in alphabetical order.

def dict_to_list(dict_in):
    keys_sort = sorted(list(dict_in.keys()))
    list_out = [(ele,dict_in[ele]) for ele in keys_sort]
    return list_out

dict1= {"D": 1, "B": 2, "C": 3}
dict2 = {"likes": 2, "dislikes": 3, "followers": 10}
print(f'dict_to_list({dict1}) : {dict_to_list(dict1)}')
print(f'dict_to_list({dict2}) : {dict_to_list(dict2)}')

# %%
# Question3
# Write a function that creates a dictionary with each (key, value) pair being the 
# (lower case, upper case) versions of a letter, respectively.
# Examples
# mapping(["p", "s"]) ➞ { "p": "P", "s": "S" }

# mapping(["a", "b", "c"]) ➞ { "a": "A", "b": "B", "c": "C" }

# mapping(["a", "v", "y", "z"]) ➞ { "a": "A", "v": "V", "y": "Y", "z": "Z" }
# Notes
# All of the letters in the input list will always be lowercase.

def mapping(list_in):
    dict_out={}
    for ele in list_in:
        dict_out[ele.lower()] = ele.upper()
    return dict_out

print(f'mapping(["p", "s"]) : {mapping(["p", "s"])}')
print(f'mapping(["a", "b", "c"]) : {mapping(["a", "b", "c"])}')
print(f'mapping(["a", "v", "y", "z"]) : {mapping(["a", "v", "y", "z"])}')

# %%
# Question4
# Write a function, that replaces all vowels in a string with a specified vowel.
# Examples
# vow_replace("apples and bananas", "u") ➞ "upplus und bununus"

# vow_replace("cheese casserole", "o") ➞ "chooso cossorolo"

# vow_replace("stuffed jalapeno poppers", "e") ➞ "steffed jelepene peppers"
# Notes
# All words will be lowercase. Y is not considered a vowel.

def vow_replace(str_in,ch):
    x = str_in
    for i in range(len(str_in)):
        if str_in[i] in ['a','e','i','o','u']:
            x = x.replace(str_in[i],ch)
    return x
    
print(f'vow_replace("apples and bananas", "u") : {vow_replace("apples and bananas", "u")}')
print(f'vow_replace(cheese casserole", "o") : {vow_replace("cheese casserole", "o")}')
print(f'vow_replace("stuffed jalapeno poppers", "e") : {vow_replace("stuffed jalapeno poppers", "e")}')

# %%
# Question5
# Create a function that takes a string as input and capitalizes a letter 
# if its ASCII code is even and returns its lower case version if its ASCII code is odd.
# Examples
# ascii_capitalize("to be or not to be!") ➞ "To Be oR NoT To Be!"

# ascii_capitalize("THE LITTLE MERMAID") ➞ "THe LiTTLe meRmaiD"

# ascii_capitalize("Oh what a beautiful morning.") ➞ "oH wHaT a BeauTiFuL moRNiNg."

def ascii_capitalize(str_in):
    x = str_in
    for i in range(len(str_in)):
        if ord(str_in[i])%2 == 0:
            x = x.replace(str_in[i],str_in[i].upper())
        else:
            x = x.replace(str_in[i],str_in[i].lower())
    return x

print(f'ascii_capitalize("to be or not to be!") : {ascii_capitalize("to be or not to be!")}')
print(f'ascii_capitalize("THE LITTLE MERMAID" : {ascii_capitalize("THE LITTLE MERMAID")}')
print(f'ascii_capitalize("Oh what a beautiful morning.") : {ascii_capitalize("Oh what a beautiful morning.")}')
